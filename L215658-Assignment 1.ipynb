# %% [markdown]
# # Introduction To Data Science – Assignment 1
#
# ---
#
# ### Sections A – B – C – D
#
# ---
#
# ***Instructions***
#
# Due Date: Sunday 18th September 2022 – 11:59PM
#
# Name the file in the format Lyyxxxx and save it as .ipynb (e.g. L201234.ipynb)
#
# Submission will be taken on **GitHub and Google Classroom (submit the .ipynb file)** - Instructions to upload onto GitHub are provided in the link https://docs.google.com/document/d/1BR1ULOGeGWJVU6Rr6Qty1FR-quVRZyRvQGII6nEs-wo/edit?usp=sharing
#
# After uploading and submitting the .ipynb file onto Google Classroom, also private comment the link to the GitHub repository.
#
# All source files needed to complete this assignment can be found on the following Google Drive link https://drive.google.com/drive/folders/1VrkaVcExGWqilSeh50WZe4gUBjmUiJ9b?usp=sharing
#
# TA Emails
#
# Section A, C - Muhammad Maarij l192347@lhr.nu.edu.pk
#
# Section B, D - Hira Ijaz l192377@lhr.nu.edu.pk
#
# Happy Coding 😊
#
# ---

# %% [markdown]
# ---
# ## Question 1
# ---

# %% [markdown]
# Define a procedure called "check_input" that takes an input as a square list of lists (2D Matrix of N x N) and returns a boolen "true" if the input is valid or "false" otherwise, according to the following criteria.
#
# 1. Each coloumn must contain numbers from between 1 and N, with no duplicates.
# 2. Each row must contain numbers from between 1 and N, with no duplicates.

# %%
# define procedure here
def check_input(array):
    rowCount = 0
    colCount = 0
    x = len(array[0])
    for i in range(0,x):
        for j in range(1,x):
            if(array[i][0]==array[i][j] or type(array[i][j])==str):
                rowCount = rowCount + 1
    
    for j in range(0,3):
        for i in range(1,3):
            if(array[0][j]==array[i][j] or type(array[i][j])==str):
                colCount = colCount + 1
    if(rowCount==0 and colCount==0):
        return True
    else:
        return False

# %%
# run this block to test code after defining the procedure

test1 = [[1, 2, 3],
        [2, 3, 1],
        [3, 1, 2]]

test2 = [[1, 2, 3, 4],
        [2, 3, 1, 3],
        [3, 1, 2, 3],
        [4, 4, 4, 4]]

test3 = [['a', 'b', 'c'],
        ['b', 'c', 'a'],
        ['c', 'a', 'b']]

print(check_input(test1)) # must return true
print(check_input(test2)) # must return false
print(check_input(test3)) # must return false
# Out:
# True
# False
# False

# %% [markdown]
# ---
# ## Question 2
# ---

# %% [markdown]
# **Part A** - Import the file "StudentMarkSheet.csv" as a Pandas DataFrame and print the information for the dataframe

# %%
import pandas as pd
df= pd.read_csv("StudentMarkSheet.csv")
print (df)
df.info()
# Out:
#         Student name  Exam name   Exam date  Marks
# 0       James Walker    Biology  05/06/2016   31.0
# 1      Velma Clemons    Biology  05/06/2016   43.0
# 2     Kibo Underwood    Biology  05/06/2016   81.0
# 3        Louis Mcgee    Biology  05/06/2016   11.0
# 4       Phyllis Paul    Biology  05/06/2016   18.0
# ..               ...        ...         ...    ...
# 195       Yen Bowers  Sociology  21/06/2016   52.0
# 196        Ryan Pena  Sociology  21/06/2016   16.0
# 197  Portia Hamilton  Sociology  21/06/2016   34.0
# 198  Sydnee Chambers  Sociology  21/06/2016   76.0
# 199      Stacy Small  Sociology  21/06/2016   96.0
#
# [200 rows x 4 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student name  200 non-null    object
#  1   Exam name     199 non-null    object
#  2   Exam date     200 non-null    object
# ...

# %% [markdown]
# **Part B** - Remove any rows that do not contain all the data. Also print the following information.
#
# 1. Number of rows before
# 2. Number of rows containing null data
# 3. Number of rows after

# %%
print("number of rows in data", len(df))
df=df.dropna(how='all')
y=len(df)
print("after dropping null-values rows",y )
df=df.dropna(how='any')
z=len(df)
print("number of rows contains null values",z)
# Out:
# number of rows in data 196
# after dropping null-values rows 196
# number of rows contains null values 196

# %% [markdown]
# **Part C** - Print all the marks along with the subject for the student named "James Walker"

# %%
print(df[df['Student name']=='James Walker'])
# Out:
#      Student name    Exam name   Exam date  Marks
# 0    James Walker      Biology  05/06/2016   31.0
# 42   James Walker    Chemistry  15/06/2016   61.0
# 71   James Walker  Mathematics  29/07/2016   23.0
# 150  James Walker      Physics  10/06/2016  100.0
# 180  James Walker    Sociology  21/06/2016   73.0

# %% [markdown]
# ---
# ## Question 3
# ---

# %% [markdown]
# **Part A** - From the DataFrame created in Question 2, calculate the average marks for each subject

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("StudentMarkSheet.csv")
df=df.dropna(how='any')
avgBiology=df[df["Exam name"]=="Biology"]
avgBiology=avgBiology["Marks"]
avgBiology=(avgBiology.sum())/(len(avgBiology))
print("Average marks in Biology are: ",avgBiology)

avgChemistry=df[df["Exam name"]=="Chemistry"]
avgChemistry=avgChemistry["Marks"]
avgChemistry=(avgChemistry.sum())/(len(avgChemistry))
print("Average marks in Chemistry are: ",avgChemistry)

avgMathematics=df[df["Exam name"]=="Mathematics"]
avgMathematics=avgMathematics["Marks"]
avgMathematics=(avgMathematics.sum())/(len(avgMathematics))
print("Average marks in Mathematics are: ",avgMathematics)

avgPhilosophy=df[df["Exam name"]=="Philosophy"]
avgPhilosophy=avgPhilosophy["Marks"]
avgPhilosophy=(avgPhilosophy.sum())/(len(avgPhilosophy))
print("Average marks in Philosophy are: ",avgPhilosophy)

# avgPhysics=df[df["Exam name"]=="Physics"]
# avgPhysics=avgPhysics["Marks"]
# avgPhysicsy=(avgPhysics.sum())/(len(avgPhysics))
# print("Average marks in Physics are: ",avgPhysics)

avgSociology=df[df["Exam name"]=="Sociology"]
avgSociology=avgSociology["Marks"]
avgSociology=(avgSociology.sum())/(len(avgSociology))
print("Average marks in Sociology are: ",avgSociology)
# Out:
# Average marks in Biology are:  47.89473684210526
# Average marks in Chemistry are:  50.57692307692308
# Average marks in Mathematics are:  48.97222222222222
# Average marks in Philosophy are:  47.270270270270274
# Average marks in Sociology are:  56.026315789473685

# %% [markdown]
# **Part B** - Using the averages you just calculated, plot a Bar Graph showing the average marks of each subject

# %%
Subject=["Biology", "Chemistry","Mathematics", "Philosophy","Sociology"]
Average=[avgBiology, avgChemistry, avgMathematics, avgSociology, avgPhilosophy]
plt.bar(Subject, Average, fc="green")
plt.show()

# %% [markdown]
# ---
# ## Question 4
# ---

# %% [markdown]
# **Part A** - Import the file "CatData.csv" and preprocess it to remove any null values

# %%
import pandas as pd
df=pd.read_csv("CatData.csv")
df.head()
n=df[df.isnull().any(axis=1)]
df=df.dropna()
print (df)
# Out:
#      Tail Length (cm)  Mass (kg)
# 0                18.1      3.750
# 1                18.6      3.800
# 2                19.5      3.250
# 3                19.3      3.450
# 4                19.0      3.650
# ..                ...        ...
# 337              20.7      4.000
# 338              20.2      3.400
# 339              19.3      3.775
# 340              21.0      4.100
# 341              19.8      3.775
#
# [342 rows x 2 columns]

# %% [markdown]
# **Part B** - Identify the independant and dependant variables (comment answer below)

# %%
# dependant variable: x
# independant variable: y

# %% [markdown]
# **Part C** - Create a linear regression model using sklearn and fit it to the data you just imported

# %%
reg=linear_model.LinearRegression()
train_x=np.array(train[["Tail Length (cm)"]])
train_y=np.array(train[["Mass (kg)"]])
reg.fit(train_x, train_y)
# Out:
# LinearRegression()

# %% [markdown]
# **Part D** - Print the values for slope and y-intercept

# %%
coefficient=reg.coef_
intercept=reg.intercept_
print("Slope: ",coefficient)
print ("Intercept: ",intercept)
# Out:
# Slope:  [[0.48913766]]
# Intercept:  [-5.57328662]

# %% [markdown]
# **Part E** - Plot a scatter graph of the original data and a regression line on the same figure (example with dummy data shown below)
#
# ![](https://drive.google.com/uc?export=view&id=1o_NAsNjfx7zAh9m-UjvWB3rta6uraKdY)

# %%
plt.xlabel("Tail length")
plt.ylabel("mass")
plt.scatter(train['Tail Length (cm)'], train['Mass (kg)'])
plt.plot(train_x,train_x*coefficient[0]+intercept, color='red')
plt.show()
